# %% [markdown]
# <img style="width: 40%; margin-right: auto; margin-left: 0" src="data:image/png;base64,...">

# %% [markdown]
# ----
#
# Dear student,
#
# welcome to the Data Science project notebook 📊📝
#
# In the following notebook, we are going to look at various techniques we learned during the lecture. We apply our knowledge to help a restaurant owner better predict her revenue. The dataset was crafted by me -- it is likely that the numbers of a real restaurant differ a lot from the ones in the dataset.
#
# Please follow these rules:
#
# * Your submission should contain **this notebook (.ipynb)** as well as the **exported PDF file**. **Zip both files** into one archive and submit this archive until **06.12.2021 13:15**.
#
# * The project is **meant to be solved alone**. This means, that you are **not allowed to share code or answers** with your colleagues. However, it I am totally **fine with googling for solution approaches or chatting with your colleagues about a problem** (as long as you don't exchange any source code or answers with them).
#
# * I am 100% fine and happy if you deepen your understanding by using methods and code which we did not cover in the lecture - just make sure to **state your sources**!
#
# * For non-coding tasks I usually stated how many words should be used at maximum. Please **try to stay within that word limit**.
#
# * Sometimes markdown (text) cells are compiled, i.e. they are not in edit mode. Double click these cells so you can edit them. **You have to work (code or write a text) in each cell which starts with a 🔨-symbol!**
#
# * If you are unsure about an answer or your solution does not fit the answer template, feel free to write your problems into the answer field. If you can describe why you struggle or why you cannot answer a question, I will pay regard to your remarks.
#
# * It is important that you put the code you used to answer a question into the notebook. If you only post a textual answer or code which does not allow to draw your conclusions, you cannot get full points for that task.
#
# * Feel free to add additional cells to this notebook (click the + button) if you need them.
#
# * If you have any questions: **Do not hesitate to contact me**. The earlier, the better :) $\rightarrow$ <a href="mailto:mail@mci-datascience.at">📬 mail@mci-datascience.at</a>
#
#
# Godspeed!
#
# Hilko
#
# ----
#
# <span style="display: none">Version: 0.0.2</span>

# %% [markdown]
# <img style="float: left; margin-right: 1em"  src="data:image/jpeg;base64,..." />
#
# ## Your first day as a data scientist
#
# "I've been waiting for you" the restaurant owner says to you.  It's your first day of work as a data scientist in a large restaurant. The restaurant offers different type of events, e.g. xmas meal, birthday party or funeral feast. Additionally, it offers eating à la cart, i.e. you can choose the number of courses (for xmas meal, birthday party and funeral feast you cannot choose the number of courses).
#
# "I'm not very good at costing and I really need help predicting my revenues better," the restaurant owner tells you.
# You've spent the last few weeks preparing well for your job. That's why you know exactly what process you need to follow now.
#
# **📝 Your assignment**:
# Write down the five steps of the **OSEMN**(!) data science process.
#
# **📚 Help**
# You can find information about the data science process in the first lecture (01 - Introduction to Data Science)
#
# **⚠️ Further Information**
# Please write down the five steps. It is **not required** to write a description for each step.

# %% [markdown]
# 🔨 The data science process consists of the following steps
#
#  ... (Your anwer here) ...

# %% [markdown]
# "You certainly keep track of past restaurant sales, don't you?" you ask the restaurant owner.
#
# "Of course - how else am I supposed to run my business?" grumbles the owner.
#
# **📝 Your assignment**:
# Think about which problems might occur in the dataset. Put yourself in the situation and think about how the restaurant owner documents sales and what problems might arise.
#
# **📚 Help**
# Think about the Semmelweis example we used in the lecture. How did we retrieve the data from his studies? Could there be a similiar problem here?
#
# **⚠️ Further Information**
# Please write down **at least two different problems which could(!) arise**. Use your imagination! Use between 30 and 100 words!

# %% [markdown]
# 🔨 ... (Your anwer here) ...

# %% [markdown]
# "That's sensitive information you're asking me to give you," says the restaurant owner.
#
# Only after a little persuasion does the restaurant manager run to her POS system and generate an export of past restaurant bookings. She deletes sensitive customer data and then hands you a USB stick with the bookings.
#
# "Well, I can't wait to see what you can do with this," the manager laughs and hands you the USB stick. "Let's get to work," you think...

# %%
# Please run this cell!
# %matplotlib inline

import math
import sklearn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from dshelper import load_bookings

# %% [markdown]
# You take the USB stick and plug it into your laptop. You're excited to get right to work on your analysis, but then ... What kind of file extension is this?

# %% [markdown]
# **📝 Your assignment**: The data export has been copied to the data directory of this notebook. Please open the `data` directory with the Windows Explorer / Mac Finder / ... and inspect the "**bookings_export.pos**". Open the dataset, e.g. with a text editor. **Can you find out the file type**? If you were successful in identifying the file type, please **import the dataset using pandas** into a **DataFrame** called **bookings_df**.
#
# **📚 Help**
# If you were unable to determine the file type and / or to load the dataset into a DataFrame please put the following content into the solution cell. You will not get any points for this task, but you can continue with solving this notebook!
#
# ``
# bookings_df = load_bookings()
# ``

# %%
🔨 ... (Your code here) ...

# %% [markdown]
# "Finally," you think to yourself as you successfully load the data set.  Even though you had hoped to get a little more done today, you pack up your laptop and head home. After all, tomorrow is another day!
# You take the USB stick and plug it into your laptop excitedly.
#
# ## Day Two - Cleaning, cleaning, cleaning 🧽
#
# Your joy will not last long... You discover some anomalies in the data that you should clean up first.
#
# "Sure - maybe I've accidentally made a mistake once. But that shouldn't be a problem, should it?" the restaurant manager replies.
#
# **📝 Your assignment**: Explain why anomalies, missing data and dirty data should be avoided in the first place. Which problems can occur if the data is not cleaned? (max. 200 words)

# %% [markdown]
# 🔨 ... (Your answer here) ...

# %% [markdown]
# **📝 Your assignment**: First, get an overview about the dataset!
# * How many columns does the dataset have?
# * How many records (== rows) does the dataset have?
# * How many null-values are there?
# * Which null-values are plausible which not (please give an explanation)? Do a **listwise remove** the unplausible null-value!
#
# **📚 Help**
# Remember how we got an overview over the dataset in the first lecture? We looked for example at the first 10 entries and got a summary... That could be a good starting point to get an overview. If you want to find out how many null-values there are, you can have a look again at the data cleaning notebook.

# %%
🔨 ... (Your code here) ...

# %% [markdown]
# 🔨 The dataset contains ... columns and ... records.
#
# There are the following null-values in the dataset:
# ... (Your answer here) ...
#
# These null-values are plausible:
# ... (Your answer here, also write why they are plausible) ...
#
# These null values are not reasoable:
# ... (Your answer here, also write why it is unplausible) ...

# %% [markdown]
# **📝 Your assignment**: Now clean the dataset, i.e. find **three outliers** and remove them. The output of the next cell should be a cleaned dataframe which does not contain the anomalies anymore. In the box below write a small text: Which anomalies did you find? How could you deal with them (i.e. write down different ways on how to handle outliers) and how did you deal with them? (max. 200 words)
#
# **📚 Help**
# To simplify your search for anomalies, I give you some hints:
#
#    1. There is **one record** in which the `type` has a spelling mistake.
#    2. **Two** columns contain (each) one unplausible value. Visualizing the dataset might help to find them...

# %%
🔨 ... (Your code here) ...

# %% [markdown]
# 🔨 There are different ways to deal with outliers: (Your answer here)
#
# I found the following anomalies / outliers:
#
# * (Your answer here). (Write how you dealt with it)
# * (Your answer here). (Write how you dealt with it)
# * (Your answer here). (Write how you dealt with it)

# %% [markdown]
# After you have cleaned the data set, you can continue with the analysis.

# %% [markdown]
# ## Day Three - Let's explore the dataset 📊
#
# *We are now going to load a cleaned dataset, so everyone explores the same dataset regardless of how you successfully you cleaned your dataset. After running the next cell, perform your calculations on the `cleaned_df` pandas DataFrame and not on the `bookings_df` anymore!*

# %%
# Please run this cell!
del bookings_df # We delete the old variable, so you cannot work accidentially on the uncleared data!

cleaned_df = pd.read_pickle('data/cleaned_bookings.pkl')

# %% [markdown]
# **📝 Your assignment**: Please do some meaningful visualizations of the dataset. At least one visualization should show the correlation between the revenue and the number of adults. Can you recognize a pattern? Find the reason for the pattern! Feel free to visualize the data with a tool of your choice (Seaborn, Matplotlib, Excel, Tableau, ...).
#
# Describe why you chose your visualizations and what they indicate. Please calculate and describe the correlation between the revenue and the number of adults and which feature could be responsible for the pattern

# %%
🔨 ... (Your code here) ...

# %% [markdown]
# 🔨 ... (Your answer here) ...

# %% [markdown]
# "Oh, that's interesting" says the enthusiastic restaurant manager. "Could you also calculate for me what the average revenue for one event is for the different types of food?"
#
# **📝 Your assignment**: Calculate the average revenue for the different types of food! Please write a short answer for the boss (max. 50 words)!
#
# **📚 Help**: The <a href="https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html">groupby-function</a> could come in handy.  Please find out the *mean* value.

# %%
🔨 ... (Your code here) ...

# %% [markdown]
# 🔨 ... (Your answer here) ...

# %% [markdown]
# ## Day Four - Building Machine Learning models 🔨🤖

# %% [markdown]
# Let's impress the restaurant's manager!
#
# **📝 Your assignment**: Create at least **three** different machine learning models to predict the revenue, given all features of the dataset except for the revenue. Additionally, compare the performance of your models!
#
# To do so, follow this structure
#
#  1. Firstly, create two new DataFrames: One with the features (i.e. everything but the revenue variable) and one with the target variable (i.e. revenue). If there is any preprocessing required for all machine learning algorithms, this is a good moment to do the preprocessing!
#  2. Do a train-test-split with 70% training data and 30% test data
#  3. For every machine learning algorithm you want to use:
#      1. Do the required preprocessing for the algorithm
#      2. Build and train the model
#      3. Test your model on the test dataset.
#  5. Compare the models' test performance. Please write a small text: Which model do you prefer? Why do you prefer this model?

# %%
🔨 ... (Your code here) ...

# %% [markdown]
# 🔨 ... (Your answer here) ...

# %% [markdown]
# ## Day Five - What could be wrong? 👩🏼‍🍳
#
# You deploy the model to production and you realize that the performance is not as good as you expected.
#
# **📝 Your assignment**: What could be reasons for this? What are methods to find out what the model does wrong?
#
# **📚 Help**: Think about what could happen wrong during data collection, model building etc. Use your imagination! To find out what the model is doing wrong, look again at the last lecture! (max. 200 words) **Important**: Please only write a text. You do not need to check your hypothesis against the dataset. Just think(!) about what could have gone wrong!

# %% [markdown]
# 🔨 ... (Your answer here) ...

# %% [markdown]
# ## Done 🏁
# Good job 🥳. You give the boss your final model. Although the model does not work perfectly -- its predictions are definitely better than the ones by your boss.
#
# ---
#
# You are done doing the small Data Science Project. Please remember to **save this file**. Then **create an PDF export and zip this notebook and the pdf**. You can then **upload you result to Sakai**, not later than 06.12.2021, 13:15. It is not neccessary to upload the data-directory.

# %% [markdown]
# #### Photo Sources
#
# * Photo by <a href="https://unsplash.com/@michaelwb?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Michael Browning</a> on <a href="https://unsplash.com/s/photos/restaurant?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>
#
# The dataset and story have been developed by me - Hilko Janßen.
